# %%
# !gpustat
# Out:
# dgx01                     Mon Sep 15 20:01:50 2025  535.183.06
# [0] NVIDIA A100-SXM4-80GB | 32°C,  ?? % | 46539 / 81920 MB | taravichet(46526M)
# [1] NVIDIA A100-SXM4-80GB | 28°C,  ?? % |    87 / 81920 MB |
# [2] NVIDIA A100-SXM4-80GB | 28°C,  ?? % |    87 / 81920 MB |
# [3] NVIDIA A100-SXM4-80GB | 29°C,  ?? % |    87 / 81920 MB |
# [4] NVIDIA A100-SXM4-80GB | 33°C,  ?? % |     1 / 81920 MB |
# [5] NVIDIA A100-SXM4-80GB | 30°C,  ?? % |     1 / 81920 MB |
# [6] NVIDIA A100-SXM4-80GB | 32°C,  ?? % | 32459 / 81920 MB | sarmistha(32446M)
# [7] NVIDIA A100-SXM4-80GB | 33°C,  ?? % | 70739 / 81920 MB | sarmistha(70726M)

# %%
# import os 
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
#can add different domains in this and increase the max document argument to get more news articles

import os
import wikipediaapi
import pandas as pd
import time
import zipfile
from tqdm import tqdm
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

# Define Wikipedia API with User-Agent
wiki_wiki = wikipediaapi.Wikipedia(
    user_agent="FinancialRAG/1.0 (ishani@example.com)", language="en"
)

# Define broad finance-related Wikipedia categories
finance_categories = [
    "Finance",
    "Stock market",
    "Banking",
    "Investment",
    "Taxation",
    "Insurance",
    "Loans",
    "Trading",
    "Cryptocurrency",
    "General Finance",
    "Mortgage",
    "Money",
    "Personal finance",
    "Debit Cards",
    "Credit Cards",
    "Finance in India",
    "Stock market in India",
    "Banking in India",
    "Investment in India",
    "Taxation in India",
    "Insurance in India",
    "Loans in India",
    "Trading in India",
    "Cryptocurrency in India",
    "General Finance in India",
    "Mortgage in India",
    "Money in India",
    "Personal finance in India",
    "Debit Cards in India",
    "Credit Cards in India",
    "Financial Laws & Regulations",
    "Anti-Money Laundering (AML)",
    "Know Your Customer (KYC)",
    "Basel Accords",
    "Dodd-Frank Act",
    "SEBI Regulations (India)",
    "RBI Policies (India)",
    "Actuarial Science",
    "Reinsurance",
    "Life Insurance",
    "Health Insurance",
    "Property & Casualty Insurance",
    "Microinsurance",
    "Real Estate Investment Trusts (REITs)",
    "Commercial Real Estate",
    "Housing Markets",
    "Real Estate Valuation",
    "Property Taxation",
    "Healthcare Finance",
    "Energy Finance",
    "Agricultural Finance",
    "Infrastructure Finance",
    "Defense & Military Finance",
    "Decentralized Finance (DeFi)",
    "Blockchain Applications in Finance",
    "AI in Financial Services",
    "Algorithmic Trading",
    "High-Frequency Trading (HFT)",
    "Web3 & Finance",
    "Quantum Computing in Finance",
    "Monetary Policy",
    "Fiscal Policy",
    "Economic Indicators",
    "Inflation & Deflation",
    "Interest Rates",
    "GDP & Economic Growth",
    "Labor Market & Employment",
    "Recession & Economic Cycles",
    "Corporate Finance",
    "Mergers and Acquisitions",
    "Private Equity",
    "Venture Capital",
    "Financial Planning",
    "Risk Management",
    "Financial Modeling",
    "Business Valuation",
    "Wealth Management",
    "Capital Markets",
    "Asset Management",
    "Treasury Management",
    "Indian Economy",
    "Monetary Policy of India",
    "Fiscal Policy of India",
    "Reserve Bank of India (RBI) Policies",
    "Union Budget of India",
    "Economic Survey of India",
    "Make in India Initiative",
    "Startup India & MSME Financing",
    "Goods and Services Tax (GST) in India",
    "Inflation in India",
    "Public Sector Banks (PSBs) in India",
    "Private Sector Banks in India",
    "Regional Rural Banks (RRBs) in India",
    "Cooperative Banks in India",
    "Non-Banking Financial Companies (NBFCs) in India",
    "Microfinance Institutions (MFIs) in India",
    "Indian Payment Banks",
    "Unified Payments Interface (UPI) & Digital Payments in India",
    "Financial Inclusion in India (Jan Dhan Yojana, PM Mudra Yojana, etc.)",
    "National Stock Exchange (NSE) & Bombay Stock Exchange (BSE)",
    "Securities and Exchange Board of India (SEBI) Regulations",
    "Sensex & Nifty Indices",
    "Mutual Funds in India",
    "Exchange-Traded Funds (ETFs) in India",
    "Commodity Trading in India",
    "Derivative Markets in India",
    "Foreign Direct Investment (FDI) in India",
    "Foreign Institutional Investors (FII) in India",
    "Angel Investing & Venture Capital in India",
    "Initial Public Offerings (IPOs) in India",
    "Direct Taxes in India (Income Tax, Corporate Tax, etc.)",
    "Indirect Taxes in India (GST, Excise Duty, Customs Duty, etc.)",
    "Tax Exemptions & Deductions under Indian Tax Laws",
    "Provident Fund (EPF, PPF, NPS) in India",
    "National Pension System (NPS) in India",
    "Public Provident Fund (PPF) in India",
    "Employee Provident Fund (EPF) in India",
    "Atal Pension Yojana (APY)",
    "Pradhan Mantri Vaya Vandana Yojana (PMVVY)",
    "Sukanya Samriddhi Yojana (SSY)",
    "Agricultural Income & Rural Taxation in India",
    "Education Loans in India",
    "Home Loans in India",
    "Agriculture & Rural Credit in India",
    "Priority Sector Lending (PSL) in India",
    "Microfinance & Self-Help Groups (SHGs) in India",
    "Credit Rating Agencies in India (CRISIL, ICRA, CARE, etc.)",
    "Insurance Regulatory and Development Authority of India (IRDAI)",
    "Life Insurance in India (LIC, HDFC Life, etc.)",
    "Health Insurance in India (Ayushman Bharat, etc.)",
    "Motor & Vehicle Insurance in India",
    "Crop Insurance (Pradhan Mantri Fasal Bima Yojana - PMFBY)",
    "Reinsurance Market in India",
    

]

def get_category_articles(category_name, depth=5, max_articles=10000):
    """
    Recursively fetch articles from a Wikipedia category up to a given depth.
    """
    category = wiki_wiki.page(f"Category:{category_name}")
    articles = set()
    queue = [(category, 0)]
    
    print(f"\nFetching articles from: {category_name}")

    while queue:
        cat, level = queue.pop(0)
        if level > depth:
            continue

        for title, page in cat.categorymembers.items():
            if page.ns == wikipediaapi.Namespace.MAIN and title not in articles:
                articles.add(title)
                print(f"Fetched {len(articles)}: {title}")

            elif page.ns == wikipediaapi.Namespace.CATEGORY:
                queue.append((page, level + 1))

            if len(articles) >= max_articles:
                return articles  # Stop if max limit is reached

    return articles

# Collect articles from all finance-related categories
all_articles = set()
for category in finance_categories:
    articles = get_category_articles(category, depth=5, max_articles=5000)
    all_articles.update(articles)

print(f"\nTotal unique articles collected: {len(all_articles)}")

# Fetch article content
documents = []
for i, title in enumerate(tqdm(all_articles, desc="Fetching Wikipedia Articles"), start=1):
    page = wiki_wiki.page(title)
    if page.exists():
        documents.append((title, page.text))
    
    if i % 5 == 0:  # Avoid hitting Wikipedia rate limits
        time.sleep(1)

# Save raw data to CSV
csv_filename = "wikipedia_finance_articles.csv"
df_articles = pd.DataFrame(documents, columns=["Title", "Content"])
df_articles.to_csv(csv_filename, index=False)

# 🔹 ZIP the extracted articles
zip_filename = "wikipedia_finance_articles.zip"
with zipfile.ZipFile(zip_filename, "w", zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(csv_filename)
    print(f"✅ Saved documents to {zip_filename}")

# Remove the original CSV after zipping
os.remove(csv_filename)

print("📂 Zipping complete. Ready for reference!")

# Split text into chunks for RAG
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=200)
split_documents = []
for title, text in documents:
    chunks = text_splitter.split_text(text)
    for chunk in chunks:
        split_documents.append((title, chunk))

# Use Hugging Face embeddings
embedding_model = HuggingFaceEmbeddings(model_name="Alibaba-NLP/gte-Qwen2-1.5B-instruct")

# Create FAISS vector store
vectorstore = FAISS.from_texts([doc[1] for doc in split_documents], embedding_model)
vectorstore.save_local("./faiss_index")
print("🔹 Vector store created successfully!")

# Load user queries
df_queries = pd.read_csv("./queries.csv")

def retrieve_context(query, vectorstore, k=10, threshold=0.3):
    results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
    filtered_results = [doc.page_content for doc, score in results if score >= threshold]
    return "\n\n---\n\n".join(filtered_results) if filtered_results else "No relevant context found."

# Retrieve and store context
df_queries["context"] = df_queries["user"].progress_apply(lambda query: retrieve_context(query, vectorstore))
df_queries.to_csv("./queries_with_context_latest.csv", index=False, encoding="utf-8", quoting=pd.io.common.csv.QUOTE_MINIMAL)
print("✅ Context saved successfully!")
# Out:
# Fetching articles from: Finance
# Fetched 1: Finance
# Fetched 2: Agricultural finance
# Fetched 3: Approved Publication Arrangement
# Fetched 4: Asset
# Fetched 5: Austerity
# Fetched 6: Bachelor of Finance
# Fetched 7: Yvon Sana Bangui
# Fetched 8: Capital Markets Union
# Fetched 9: Capitalism
# Fetched 10: CGAP (Thinktank)
# Fetched 11: Climate finance in Zimbabwe
# Fetched 12: Ettore Conti of Verampio, Count of Verampio
# Fetched 13: Designated Professional Body
# Fetched 14: DreamAhead College Investment Plan
# Fetched 15: Exit (investing)
# Fetched 16: Financial Modeling World Cup
# Fetched 17: Financial stability
# Fetched 18: Industrial and provident society
# Fetched 19: Just Energy Transition Partnership
# Fetched 20: Lynnette Khalfani-Cox
# Fetched 21: Liquidation
# Fetched 22: Look-through earnings
# Fetched 23: Master of Applied Finance
# Fetched 24: Master of Finance
# Fetched 25: Microsoft Excel Collegiate Challenge
# Fetched 26: Morningstar Rating for Funds
# Fetched 27: Non-financial asset
# Fetched 28: Online portfolio selection
# Fetched 29: P2P asset management
# Fetched 30: PERC Reporting Standard
# Fetched 31: Private market assets
# Fetched 32: Profit motive
# Fetched 33: Public commercial assets
# Fetched 34: Public sector balance sheet
# Fetched 35: Public sector net worth
# Fetched 36: Public wealth fund
# Fetched 37: Real bills doctrine
# Fetched 38: Renting
# Fetched 39: Request for quote
# Fetched 40: Shadow banking in China
# Fetched 41: TaxCOOP
# Fetched 42: Trade exchange
# Fetched 43: Trapdoor (finance)
# Fetched 44: Tredefina
# Fetched 45: Intangible asset finance
# Fetched 46: Transport finance
# Fetched 47: Outline of finance
# Fetched 48: List of business and finance abbreviations
# Fetched 49: List of American exchange-traded funds
# Fetched 50: Asset management in Malaysia
# Fetched 51: Asset management in Singapore
# Fetched 52: List of asset management firms
# Fetched 53: List of banking crises
# Fetched 54: List of bond market indices
# Fetched 55: List of electronic trading protocols
# Fetched 56: List of financial performance measures
# Fetched 57: Financial Secrecy Index
# Fetched 58: List of futures exchanges
# Fetched 59: Global assets under management
# Fetched 60: Global Financial Centres Index
# Fetched 61: List of government bonds
# Fetched 62: List of International Financial Reporting Standards
# Fetched 63: List of Australian exchange-traded funds
# Fetched 64: List of financial data feeds
# Fetched 65: List of financial economics articles
# Fetched 66: List of financial regulatory authorities by jurisdiction
# Fetched 67: List of investors in Bernard L. Madoff Investment Securities
# Fetched 68: Outline of corporate finance
# Fetched 69: Index of real estate articles
# Fetched 70: List of REITs in Canada
# Fetched 71: Altarage
# Fetched 72: Bank im Bistum Essen
# Fetched 73: Benefice
# Fetched 74: CajaSur
# Fetched 75: Cathedraticum
# Fetched 76: Chop-church
# Fetched 77: Church tax
# Fetched 78: Episcopal subsidy
# Fetched 79: Fabrica ecclesiae
# Fetched 80: Hochstift
# Fetched 81: Indulgence
# Fetched 82: Just price
# Fetched 83: Mass stipend
# Fetched 84: Mense
# Fetched 85: Pax-Bank
# Fetched 86: Peter's Pence
# Fetched 87: Pouillé (ecclesiastical register)
# Fetched 88: Precarium
# Fetched 89: Steyler Bank
# Fetched 90: Temporalities
# Fetched 91: Treaties between the Republic of Croatia and the Holy See
# Fetched 92: Candlestick chart
# Fetched 93: DataScene
# Fetched 94: Heikin-Ashi chart
# Fetched 95: Kagi chart
# Fetched 96: Line break chart
# Fetched 97: Line chart
# Fetched 98: MIDAS technical analysis
# Fetched 99: Open-high-low-close chart
# Fetched 100: Order flow trading
# Fetched 101: Point and figure chart
# Fetched 102: Renko chart
# Fetched 103: Analytics
# Fetched 104: Brainware
# Fetched 105: Budget analyst
# Fetched 106: Business intelligence
# Fetched 107: Corporate finance analyst
# Fetched 108: Corporate surveillance
# Fetched 109: Cost analyst
# Fetched 110: Credit Benchmark
# Fetched 111: Debt Sustainability Analysis
# Fetched 112: Economic analyst
# Fetched 113: Financial analyst
# Fetched 114: Financial econometrics
# Fetched 115: FP&A
# Fetched 116: Mobile business intelligence
# Fetched 117: Net capital outflow
# Fetched 118: Risk analyst
# Fetched 119: Risk manager
# Fetched 120: Decentralized finance
# Fetched 121: Stablecoin
# Fetched 122: World Liberty Financial
# Fetched 123: Financial centre
# Fetched 124: List of financial districts
# Fetched 125: Aura Erbil
# Fetched 126: Beirut Central District
# Fetched 127: Bonifacio Global City
# Fetched 128: Borgartún
# Fetched 415: Added value
# Fetched 416: Alpha (finance)
# Fetched 417: AlphaIC
# Fetched 418: Altman Z-score
# Fetched 419: Asset turnover
# Fetched 420: Average accounting return
# Fetched 421: Average propensity to consume
# Fetched 422: Average propensity to save
# Fetched 423: Basic Earnings Per Share
# Fetched 424: Beneish M-score
# Fetched 425: Beta (finance)
# Fetched 426: Bias ratio
# Fetched 427: Bid-to-cover ratio
# Fetched 428: Buffett indicator
# Fetched 429: Calmar ratio
# Fetched 430: Capital adequacy ratio
# Fetched 431: Capital recovery factor
# Fetched 432: Capitalization rate
# Fetched 433: CASA ratio
# Fetched 434: Cash conversion cycle
# Fetched 435: Cash return on capital invested
# Fetched 436: Cash-flow return on investment
# Fetched 437: Cost accrual ratio
# Fetched 438: Current ratio
# Fetched 439: Cyclically adjusted price-to-earnings ratio
# Fetched 440: Days in inventory
# Fetched 441: Days payable outstanding
# Fetched 442: Days sales outstanding
# Fetched 443: Debt ratio
# Fetched 444: Debt service coverage ratio
# Fetched 445: Debt service ratio
# Fetched 446: Debt-to-capital ratio
# Fetched 447: Debt-to-equity ratio
# Fetched 448: Debt-to-income ratio
# Fetched 449: Debtor collection period
# Fetched 450: Debtor days
# Fetched 451: Deleveraging
# Fetched 452: Dividend cover
# Fetched 453: Dividend payout ratio
# Fetched 454: Dividend yield
# Fetched 455: DuPont analysis
# Fetched 456: Earnings per share
# Fetched 457: Earnings yield
# Fetched 458: Economy monetization
# Fetched 459: Effective gross income
# Fetched 460: Efficiency ratio
# Fetched 461: Envy ratio
# Fetched 462: Equity ratio
# Fetched 463: EV/GCI
# Fetched 464: Enterprise value-to-sales ratio
# Fetched 465: EV/Ebitda
# Fetched 466: Expense ratio
# Fetched 467: Feed ratio
# Fetched 468: Financial result
# Fetched 469: Fixed-asset turnover
# Fetched 470: Greeks (finance)
# Fetched 471: Gross margin
# Fetched 472: Hansen–Jagannathan bound
# Fetched 473: High-yield stock
# Fetched 474: Import ratio
# Fetched 475: Incremental capital-output ratio
# Fetched 476: Infection ratio
# Fetched 477: Information ratio
# Fetched 478: Inventory turnover
# Fetched 479: Jaws ratio
# Fetched 480: Leverage cycle
# Fetched 481: Leverage ratio
# Fetched 482: Like for like
# Fetched 483: Loan-to-value ratio
# Fetched 484: Loss ratio
# Fetched 485: Market-Adjusted Performance Indicator
# Fetched 486: Net income per employee
# Fetched 487: Net interest income
# Fetched 488: Net interest margin
# Fetched 489: Net interest spread
# Fetched 490: Ohlson O-score
# Fetched 491: Omega ratio
# Fetched 492: Operating leverage
# Fetched 493: Operating margin
# Fetched 494: Operating ratio
# Fetched 495: P/B ratio
# Fetched 496: PEG ratio
# Fetched 497: Price-to-cash flow ratio
# Fetched 498: Price–earnings ratio
# Fetched 499: Price–sales ratio
# Fetched 500: Profit margin
# Fetched 501: Put/call ratio
# Fetched 502: Quick ratio
# Fetched 503: Rachev ratio
# Fetched 504: Rate of return
# Fetched 505: Rate of return on a portfolio
# Fetched 506: Rate of return pricing
# Fetched 507: Receivables turnover ratio
# Fetched 508: Reserve requirement
# Fetched 509: Retention ratio
# Fetched 510: Return of capital
# Fetched 511: Return on assets
# Fetched 512: Return on brand
# Fetched 513: Return on capital
# Fetched 514: Return on capital employed
# Fetched 515: Return on equity
# Fetched 516: Return on modeling effort
# Fetched 517: Return on net assets
# Fetched 518: Return on tangible equity
# Fetched 519: Risk-adjusted return on capital
# Fetched 520: Risk–return ratio
# Fetched 521: Sales density
# Fetched 522: Sharpe ratio
# Fetched 523: Short interest ratio
# Fetched 524: Social earnings ratio
# Fetched 525: Social return on investment
# Fetched 526: Sortino ratio
# Fetched 527: Statutory liquidity ratio
# Fetched 528: Sterling ratio
# Fetched 529: Sustainable growth rate
# Fetched 530: Sustainable return on investment
# Fetched 531: Texas ratio
# Fetched 532: Theoretical ex-rights price
# Fetched 533: Times interest earned
# Fetched 534: Tobin's q
# Fetched 535: Total expense ratio
# Fetched 536: Total revenue share
# Fetched 537: Treynor ratio
# Fetched 538: Upside potential ratio
# Fetched 539: V2 ratio
# Fetched 540: Yield gap
# Fetched 541: Absorbing barrier (finance)
# Fetched 542: Annualized loss expectancy
# Fetched 543: Bielard, Biehl and Kaiser five-way model
# Fetched 544: Barnewall Two-way Model
# Fetched 545: Cash flow hedge
# Fetched 546: Counter party risk
# Fetched 547: Credit conversion factor
# Fetched 548: Deposit risk
# Fetched 549: Drawdown (economics)
# Fetched 550: Economic capital
# Fetched 551: Endogenous risk
# Fetched 552: Electricity price area
# Fetched 553: European Systemic Risk Board
# Fetched 554: Expected loss
# Fetched 555: Expected return
# Fetched 556: Favourite-longshot bias
# Fetched 557: Fixed bill
# Fetched 558: Government risk
# Fetched 559: Liquidity risk
# Fetched 560: Macro risk
# Fetched 561: Maximum downside exposure
# Fetched 562: Model risk
# Fetched 563: Moral hazard
# Fetched 564: ORRF Risk Research Forum
# Fetched 565: Over-the-counter (finance)
# Fetched 566: PnL explained
# Fetched 567: Principled reasoning
# Fetched 568: Product control
# Fetched 569: Reputational damage
# Fetched 570: Risk metric
# Fetched 571: Risk neutral preferences
# Fetched 572: Risk of ruin
# Fetched 573: Risk-free bond
# Fetched 574: Risk-free rate
# Fetched 575: Risk-seeking
# Fetched 576: Risk-weighted asset
# Fetched 577: Security agreement
# Fetched 578: Settlement risk
# Fetched 579: Single-loss expectancy
# Fetched 580: Specific risk
# Fetched 581: State prices
# Fetched 582: Systematic risk
# Fetched 583: Systemic risk
# Fetched 584: Tail risk
# Fetched 585: Taleb distribution
# Fetched 586: Time at risk
# Fetched 587: Trading room
# Fetched 588: Valuation control
# Fetched 589: Valuation risk
# Fetched 590: Value investing
# Fetched 591: Volatility risk
# Fetched 592: Wrong way risk
# Fetched 593: Financial services
# Fetched 594: Access to finance
# Fetched 595: Alternative finance
# Fetched 596: Alternative financial service
# Fetched 597: Capital market
# Fetched 598: Certified Risk Professional
# Fetched 599: Christian finance
# Fetched 600: Collective trust fund
# Fetched 601: Commission sharing agreement
# Fetched 602: Credit union
# Fetched 603: Current (financial services company)
# Fetched 604: Deposit account
# Fetched 789: Composite (finance)
# Fetched 790: Compuscan
# Fetched 791: Conditional dismissal
# Fetched 792: Consolidated Quotation System
# Fetched 793: Constitutional Research Council
# Fetched 794: Consumption-based capital asset pricing model
# Fetched 795: Contingent beneficiary
# Fetched 796: Continuous payment authority
# Fetched 797: Convenience translation
# Fetched 798: Cornmarket Group Financial Services
# Fetched 799: Cost of funds index
# Fetched 800: Coupon leverage
# Fetched 801: Credit circle
# Fetched 802: Credit clearing
# Fetched 803: Credit reference
# Fetched 804: Credit union league
# Fetched 805: Creditor Reference
# Fetched 806: Criminal Finances Act 2017
# Fetched 807: Crossing network
# Fetched 808: Currency strength
# Fetched 809: Current yield
# Fetched 810: Cut off period
# Fetched 811: Date rolling
# Fetched 812: The Death of Money
# Fetched 813: Debit spread
# Fetched 814: Deferred financing cost
# Fetched 815: Deficit reduction
# Fetched 816: Demerger
# Fetched 817: Deposit Insurance Corporation of Japan
# Fetched 818: Depozitarul Central
# Fetched 819: Development finance institution
# Fetched 820: Devolvement
# Fetched 821: Diploma of Financial Studies
# Fetched 822: Direct carrier billing
# Fetched 823: Direct debit dividend contributions
# Fetched 824: Direct finance
# Fetched 825: Direct participation program
# Fetched 826: Directo a México
# Fetched 827: Discourse About the Provision of Money
# Fetched 828: Dispute (credit card)
# Fetched 829: Double digital option
# Fetched 830: Double indemnity
# Fetched 831: Drag-along right
# Fetched 832: Dubai Financial Services Authority
# Fetched 833: Dundee Stock Exchange
# Fetched 834: E-accounting
# Fetched 835: E-micro
# Fetched 836: Earnings at risk
# Fetched 837: Efficient frontier
# Fetched 838: Emphasis of matter
# Fetched 839: Employees Retirement System of Texas
# Fetched 840: Envelope system
# Fetched 841: Equal housing lender
# Fetched 842: Equated monthly installment
# Fetched 843: Equity capital markets
# Fetched 844: Erudio Student Loans
# Fetched 845: EServGlobal
# Fetched 846: Eurobond (external bond)
# Fetched 847: Euroclear Belgium
# Fetched 848: Euroclear Finland
# Fetched 849: Euroclear Nederland
# Fetched 850: Euroclear Sweden
# Fetched 851: Euronext Clearing
# Fetched 852: European Finance Association
# Fetched 853: European Multilateral Clearing Facility N.V.
# Fetched 854: Eurosystem Collateral Management System
# Fetched 855: Every Man His Own Broker
# Fetched 856: Exchange Equalisation Account
# Fetched 857: Exchange for ETF
# Fetched 858: Exchange of futures for physicals
# Fetched 859: Exchange of futures for swaps
# Fetched 860: Exit consent
# Fetched 861: Expected commercial value
# Fetched 862: Expiration (options)
# Fetched 863: Fama–MacBeth regression
# Fetched 864: Farm Credit of New Mexico
# Fetched 865: Federal Reserve Statistical Release H.4.1
# Fetched 866: Federal Reserve Statistical Release H.15
# Fetched 867: Fedwire Securities Service
# Fetched 868: Feeder fund
# Fetched 869: Fen (currency)
# Fetched 870: Fidelity Contrafund
# Fetched 871: Fiduciary trust
# Fetched 872: Finance & Development
# Fetched 873: Finance charge
# Fetched 874: Financial asset securitization investment trust
# Fetched 875: Financial compensation
# Fetched 876: Financial data processor
# Fetched 877: Financial forecast
# Fetched 878: Financial infidelity
# Fetched 65: AIG Financial Products
# Fetched 66: Marshall A. Cohen
# Fetched 67: William Cohen
# Fetched 68: Commodity Futures Modernization Act of 2000
# Fetched 69: Corebridge Financial
# Fetched 70: Martin Feldstein
# Fetched 71: Mansfield Freeman
# Fetched 72: Jacob A. Frenkel
# Fetched 73: Fuji Fire and Marine Insurance
# Fetched 74: Carla Anderson Hills
# Fetched 75: Richard Holbrooke
# Fetched 76: Home State Life Insurance Company
# Fetched 77: Constance Hunter
# Fetched 78: International Finance Center Seoul
# Fetched 79: Donald P. Kanak
# Fetched 80: Thomas Leonardi
# Fetched 81: Arthur Levitt
# Fetched 82: Maiden Lane Transactions
# Fetched 83: Edwin Manton
# Fetched 84: Anand Panyarachun
# Fetched 85: PineBridge Investments
# Fetched 86: Thomas R. Savage
# Fetched 87: Stowe Mountain Resort
# Fetched 88: Michael H. Sutton
# Fetched 89: Travel Guard
# Fetched 90: Vivacom
# Fetched 91: Vivatel
# Fetched 92: Yussur A. F. Abrar
# Fetched 93: Ang Wei Neng
# Fetched 94: Pedro Aspe
# Fetched 95: Bob Benmosche
# Fetched 96: Stephen Bollenbach
# Fetched 97: Dave Cayemitte
# Fetched 98: Pei-yuan Chia
# Fetched 99: W. Don Cornwell
# Fetched 100: Florence A. Davis
# Fetched 101: Brian Duperreault
# Fetched 102: Lucy Fato
# Fetched 103: Sinéad Goldrick
# Fetched 104: Harvey Golub
# Fetched 105: Maurice R. Greenberg
# Fetched 106: Peter Hancock (businessman)
# Fetched 107: Meghan Hays
# Fetched 108: Suzanne Nora Johnson
# Fetched 109: Ed Liddy
# Fetched 110: Donald McFarlane
# Fetched 111: Steve Miller (automotive industry executive)
# Fetched 112: Morris W. Offit
# Fetched 113: Perry Rotella
# Fetched 114: Thomas A. Russo
# Fetched 115: Cornelius Vander Starr
# Fetched 116: Douglas Steenland
# Fetched 117: Barry Stowe
# Fetched 118: Martin J. Sullivan
# Fetched 119: Robert B. Willumstad
# Fetched 120: Frank G. Wisner
# Fetched 121: Peter Zaffino
#
# Fetching articles from: Life Insurance
#
# Fetching articles from: Health Insurance
#
# Fetching articles from: Property & Casualty Insurance
#
# Fetching articles from: Microinsurance
# Fetched 1: Microinsurance
# Fetched 2: Rose Goslinga
# Fetched 3: Andrew Kuper
# Fetched 4: MicroInsurance Centre
# Fetched 5: Grama Vidiyal
# Fetched 6: Milvik
#
# Fetching articles from: Real Estate Investment Trusts (REITs)
#
# Fetching articles from: Commercial Real Estate
#
# Fetching articles from: Housing Markets
#
# Fetching articles from: Real Estate Valuation
#
# Fetching articles from: Property Taxation
#
# Fetching articles from: Healthcare Finance
#
# Fetching articles from: Energy Finance
#
# Fetching articles from: Agricultural Finance
#
# Fetching articles from: Infrastructure Finance
#
# Fetching articles from: Defense & Military Finance
#
# Fetching articles from: Decentralized Finance (DeFi)
#
# Fetching articles from: Blockchain Applications in Finance
#
# Fetching articles from: AI in Financial Services
#
# Fetching articles from: Algorithmic Trading
#
# Fetching articles from: High-Frequency Trading (HFT)
#
# Fetching articles from: Web3 & Finance
#
# Fetching articles from: Quantum Computing in Finance
#
# Fetching articles from: Monetary Policy
#
# Fetching articles from: Fiscal Policy
#
# Fetching articles from: Economic Indicators
#
# Fetching articles from: Inflation & Deflation
#
# Fetching articles from: Interest Rates
#
# Fetching articles from: GDP & Economic Growth
#
# Fetching articles from: Labor Market & Employment
#
# Fetching articles from: Recession & Economic Cycles
#
# Fetching articles from: Corporate Finance
#
# Fetching articles from: Mergers and Acquisitions
#
# Fetching articles from: Private Equity
#
# Fetching articles from: Venture Capital
#
# Fetching articles from: Financial Planning
#
# Fetching articles from: Risk Management
#
# Fetching articles from: Financial Modeling
#
# Fetching articles from: Business Valuation
#
# Fetching articles from: Wealth Management
#
# Fetching articles from: Capital Markets
#
# Fetching articles from: Asset Management
#
# Fetching articles from: Treasury Management
#
# Fetching articles from: Indian Economy
#
# Fetching articles from: Monetary Policy of India
#
# Fetching articles from: Fiscal Policy of India
#
# Fetching articles from: Reserve Bank of India (RBI) Policies
#
# Fetching articles from: Union Budget of India
#
# Fetching articles from: Economic Survey of India
#
# Fetching articles from: Make in India Initiative
#
# Fetching articles from: Startup India & MSME Financing
#
# Fetching articles from: Goods and Services Tax (GST) in India
#
# Fetching articles from: Inflation in India
#
# Fetching articles from: Public Sector Banks (PSBs) in India
#
# Fetching articles from: Private Sector Banks in India
#
# Fetching articles from: Regional Rural Banks (RRBs) in India
#
# Fetching articles from: Cooperative Banks in India
#
# Fetching articles from: Non-Banking Financial Companies (NBFCs) in India
#
# Fetching articles from: Microfinance Institutions (MFIs) in India
#
# Fetching articles from: Indian Payment Banks
#
# Fetching articles from: Unified Payments Interface (UPI) & Digital Payments in India
#
# Fetching articles from: Financial Inclusion in India (Jan Dhan Yojana, PM Mudra Yojana, etc.)
#
# Fetching articles from: National Stock Exchange (NSE) & Bombay Stock Exchange (BSE)
#
# Fetching articles from: Securities and Exchange Board of India (SEBI) Regulations
#
# Fetching articles from: Sensex & Nifty Indices
#
# Fetching articles from: Mutual Funds in India
#
# Fetching articles from: Exchange-Traded Funds (ETFs) in India
#
# Fetching articles from: Commodity Trading in India
#
# Fetching articles from: Derivative Markets in India
#
# Fetching articles from: Foreign Direct Investment (FDI) in India
#
# Fetching articles from: Foreign Institutional Investors (FII) in India
#
# Fetching articles from: Angel Investing & Venture Capital in India
#
# Fetching articles from: Initial Public Offerings (IPOs) in India
#
# Fetching articles from: Direct Taxes in India (Income Tax, Corporate Tax, etc.)
#
# Fetching articles from: Indirect Taxes in India (GST, Excise Duty, Customs Duty, etc.)
#
# Fetching articles from: Tax Exemptions & Deductions under Indian Tax Laws
#
# Fetching articles from: Provident Fund (EPF, PPF, NPS) in India
#
# Fetching articles from: National Pension System (NPS) in India
#
# Fetching articles from: Public Provident Fund (PPF) in India
#
# Fetching articles from: Employee Provident Fund (EPF) in India
#
# Fetching articles from: Atal Pension Yojana (APY)
#
# Fetching articles from: Pradhan Mantri Vaya Vandana Yojana (PMVVY)
#
# Fetching articles from: Sukanya Samriddhi Yojana (SSY)
#
# Fetching articles from: Agricultural Income & Rural Taxation in India
#
# Fetching articles from: Education Loans in India
#
# Fetching articles from: Home Loans in India
#
# Fetching articles from: Agriculture & Rural Credit in India
#
# Fetching articles from: Priority Sector Lending (PSL) in India
#
# Fetching articles from: Microfinance & Self-Help Groups (SHGs) in India
#
# Fetching articles from: Credit Rating Agencies in India (CRISIL, ICRA, CARE, etc.)
#
# Fetching articles from: Insurance Regulatory and Development Authority of India (IRDAI)
#
# Fetching articles from: Life Insurance in India (LIC, HDFC Life, etc.)
#
# Fetching articles from: Health Insurance in India (Ayushman Bharat, etc.)
#
# Fetching articles from: Motor & Vehicle Insurance in India
#
# Fetching articles from: Crop Insurance (Pradhan Mantri Fasal Bima Yojana - PMFBY)
#
# Fetching articles from: Reinsurance Market in India
#
# Total unique articles collected: 27970
# Fetching Wikipedia Articles:  16%|█▌        | 4438/27970 [1:12:58<6:03:12,  1.08it/s] IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
#this code block will return the contexts
import os
import pandas as pd
from tqdm import tqdm
from dotenv import load_dotenv
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from huggingface_hub import login
import csv

# Load environment variables
load_dotenv()

# Define paths
csv_knowledge_base_path = "./wikipedia_finance_articles.csv"  # Now using CSV instead of ZIP
csv_queries_path = "./user_queries.csv"
vectorstore_path = "./faiss_index"
output_csv_path = "./queries_with_context_latest.csv"

# Login to Hugging Face
login("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")

# Use a consistent embedding model
embedding_model = HuggingFaceEmbeddings(model_name="Alibaba-NLP/gte-Qwen2-1.5B-instruct")

# Function to load and chunk documents from CSV
def load_and_chunk_csv(csv_path):
    all_documents = []
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=200)

    print(f"Loading CSV knowledge base from {csv_path}...")
    
    df = pd.read_csv(csv_path)
    
    if "Content" not in df.columns:
        raise ValueError("CSV file must contain a 'content' column with news articles.")

    print(f"Processing {len(df)} news articles...")
    
    for index, row in tqdm(df.iterrows(), total=len(df), desc="Splitting content"):
        text = row["Content"]
        chunks = text_splitter.split_text(text)
        
        for chunk in chunks:
            all_documents.append(chunk)

    print(f"Total document chunks created: {len(all_documents)}")
    return all_documents

# Function to create FAISS vector store from CSV content
def create_vector_store(csv_path, vectorstore_path):
    print("Loading and chunking documents...")
    documents = load_and_chunk_csv(csv_path)
    
    if not documents:
        raise ValueError("No documents found in the knowledge base.")

    print("Creating FAISS vector store...")
    vectorstore = FAISS.from_texts(tqdm(documents, desc="Indexing documents"), embedding_model)
    vectorstore.save_local(vectorstore_path)
    
    print("Vector store created successfully.")
    return vectorstore

# Function to load or rebuild FAISS vector store
def load_or_create_vector_store(csv_path, vectorstore_path):
    if os.path.exists(vectorstore_path):
        print("FAISS index found. Deleting and recreating to avoid embedding mismatch...")
        os.system(f"rm -rf {vectorstore_path}")  # Remove old index
    return create_vector_store(csv_path, vectorstore_path)

# Function to load user queries
def load_queries(csv_path):
    try:
        print("Loading user queries...")
        df = pd.read_csv(csv_path)
        if "user" not in df.columns:
            raise ValueError("CSV file must contain a 'user' column.")
        print("User queries loaded successfully.")
        return df
    except Exception as e:
        print(f"Error loading queries: {e}")
        return None

# Function to retrieve context for queries
def retrieve_context(query, vectorstore, k=10, threshold=0.3):
    results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
    filtered_results = [doc.page_content for doc, score in results if score >= threshold]
    
    if not filtered_results:
        return "No relevant context found."
    
    return "\n\n---\n\n".join(filtered_results)

# Function to retrieve and store context for all queries with tqdm
def retrieve_and_store_context(df, vectorstore, output_csv_path):
    tqdm.pandas(desc="Retrieving context")
    print("Retrieving context for queries...")
    
    df["context"] = df["user"].progress_apply(lambda query: retrieve_context(query, vectorstore))
    
    df.to_csv(output_csv_path, index=False, encoding="utf-8", quoting=csv.QUOTE_MINIMAL)
    print(f"✅ Context saved to {output_csv_path}")

# Execute the pipeline
print("Processing knowledge base (CSV-based)...")
vectorstore = load_or_create_vector_store(csv_knowledge_base_path, vectorstore_path)
df_queries = load_queries(csv_queries_path)

if df_queries is not None:
    retrieve_and_store_context(df_queries, vectorstore, output_csv_path)
# Out:
# Retrieving context:  43%|█████████████████████████████████████████▋                                                       | 1723/4006 [00:56<01:13, 31.12it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.1260111705543242), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.035198704767053224), (Document(id='d3d44fbc-79c9-4683-8ad5-6e39f4f35304', metadata={}, page_content="Agricultural sector depends significantly on external factors such as the weather, pest and disease outbreaks and prices of inputs and outputs, which are beyond the farmers' control. This translates to additional risks for agricultural financial institutions. These risks are exacerbated by the fact that they are common for most or all farmers in the area. For rural\nfinancial institutions, this translates into considerable portfolio risk.\nLow population densities and poor infrastructure result in high transaction costs for rural financial service providers and for their clients. This increases the costs of financial services, thereby reducing the effective demand for loans. \nAdditionally, agriculture is a politically sensitive topic, prone to government interventions, such as:"), 0.02376359041647147), (Document(id='81493b73-d890-4f77-bf87-35a75cbd6875', metadata={}, page_content="Financial planning and forecasting\nCapital budgeting\nCapital structure\nWorking capital management\nRisk management\nFinancial analysis and reporting.\nThe discussion, however, extends to business strategy more broadly, emphasizing alignment with the company's overall strategic objectives; and similarly incorporates the managerial perspectives of planning, directing, and controlling.\n\nFinancial economics\nFinancial economics is the branch of economics that studies the interrelation of financial variables, such as prices, interest rates and shares, as opposed to real economic variables, i.e. goods and services. It thus centers on pricing, decision making, and risk management in the financial markets, and produces many of the commonly employed financial models. (Financial econometrics is the branch of financial economics that uses econometric techniques to parameterize the relationships suggested.)\nThe discipline has two main areas of focus: asset pricing and corporate finance; the first being the perspective of providers of capital, i.e. investors, and the second of users of capital; respectively:"), -0.02022718271677415), (Document(id='a72385c4-4d6c-4a88-a221-95fda6e17d7c', metadata={}, page_content='Quantum finance involves applying quantum mechanical approaches to financial theory, providing novel methods and perspectives in the field.  Quantum finance is an interdisciplinary field, in which theories and methods developed by quantum physicists and economists are applied to solve financial problems. It represents a branch known as econophysics. Although quantum computational methods have been around for quite some time and use the basic principles of physics to better understand the ways to implement and manage cash flows, it is mathematics that is actually important in this new scenario Finance theory is heavily based on financial instrument pricing such as stock option pricing. Many of the problems facing the finance community have no known analytical solution. As a result, numerical methods and computer simulations for solving these problems have proliferated. This research area is known as computational finance. Many computational finance problems have a high degree of computational complexity and are slow to converge to a solution on classical computers. In particular, when it comes to option pricing, there is additional complexity resulting from the need to respond to'), -0.028316427351469997), (Document(id='d0f8cb97-43fb-4b1e-ab ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  45%|███████████████████████████████████████████▊                                                     | 1811/4006 [00:58<01:10, 30.96it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.0784392639968049), (Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on the management of personal finances;\nUnderstanding the effects of credit on individual financial standing;\nDeveloping a savings plan or financing for large purchases (auto, education, home);\nPlanning a secure financial future in an environment of economic instability;\nPursuing a checking or a savings account;\nPreparing for retirement or other long term expenses.'), 0.059826878519606), (Document(id='7d9f406a-72e2-4ce9-9b3e-4e6de3e4a143', metadata={}, page_content='Areas of finance\nAs outlined, finance comprises, broadly, the three areas of personal finance, corporate finance, and public finance.These, in turn, overlap and employ various activities and sub-disciplines—chiefly investments, risk management, and quantitative finance.\n\nPersonal finance\nPersonal finance refers to the practice of budgeting to ensure enough funds are available to meet basic needs, while ensuring there is only a reasonable level of risk to lose said capital. Personal finance may involve paying for education, financing durable goods such as real estate and cars, buying insurance, investing, and saving for retirement. Personal finance may also involve paying for a loan or other debt obligations. The main areas of personal finance are considered to be income, spending, saving, investing, and protection. The following steps, as outlined by the Financial Planning Standards Board, suggest that an individual will understand a potentially secure personal finance plan after:'), 0.05086865016231257), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.023830266730815675), (Document(id='d0f8cb97-43fb-4b1e-ab7d-5231c3d80437', metadata={}, page_content='Public finance\nPublic finance describes finance as related to sovereign states, sub-national entities, and related public entities or agencies. It generally encompasses a long-term strategic perspective regarding investment decisions that affect public entities. These long-term strategic periods typically encompass five or more years. Public finance is primarily concerned with:'), -0.022727586651531517), (Document(id='90cb692e-ab61-4d21-a167-a93e3c0c5332', metadata={}, page_content='External links\n\nFinance Definition (Investopedia)\nHypertextual Finance Glossary (Campbell Harvey)\nFinance Glossary (Pierre Vernimmen)\nGlossary of financial risk management terms (Risk.net)\nGlossary of Key Investment Terms (PIMCO)\nCorporate finance resources (Aswath Damodaran)\nFinancial management resources (James Van Horne)\nPersonal finance resources (Financial Literacy and Education Commission, mymoney.gov)\nPublic finance resources (Governance and Social Development Resource Centre, gsdrc.org) [Archived 2023-06-02 at the Wayback Machine]\nRisk management resources (Global Risk Institute)'), -0.04448648725115967), (Document(id='dc0b3218-e165-43ae-84c0-83fa1decff28', metadata={}, page_content='Corporate finance\nCorporate finance deals with the actions that managers take to increase the value of the firm to the shareholders, the sources of funding and the capital structure of corporations, and the tools and analysis used to allocate financial resources. While corporate finance is in principle different from managerial finance, which studies the financial management of all firms rather than corporations alone, the concepts are applicable  ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  46%|████████████████████████████████████████████▏                                                    | 1827/4006 [00:59<01:09, 31.15it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.21627193409458767), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.16595643628640322), (Document(id='76187b9e-56ac-4c99-a59e-2f8d28ac4da4', metadata={}, page_content='Risk management\nRisk management, in general, is the study of how to control risks and balance the possibility of gains; it is the process of measuring risk and then developing and implementing strategies to manage that risk. \nFinancial risk management is the practice of protecting corporate value against financial risks, often by "hedging" exposure to these using financial instruments. The focus is particularly on credit and market risk, and in banks, through regulatory capital, includes operational risk.'), 0.03193426276249045), (Document(id='d3d44fbc-79c9-4683-8ad5-6e39f4f35304', metadata={}, page_content="Agricultural sector depends significantly on external factors such as the weather, pest and disease outbreaks and prices of inputs and outputs, which are beyond the farmers' control. This translates to additional risks for agricultural financial institutions. These risks are exacerbated by the fact that they are common for most or all farmers in the area. For rural\nfinancial institutions, this translates into considerable portfolio risk.\nLow population densities and poor infrastructure result in high transaction costs for rural financial service providers and for their clients. This increases the costs of financial services, thereby reducing the effective demand for loans. \nAdditionally, agriculture is a politically sensitive topic, prone to government interventions, such as:"), 0.02583418079011468), (Document(id='85a1cdd5-494e-461f-8d47-199729cd13b7', metadata={}, page_content='Finance refers to monetary resources and to the study and discipline of money, currency, assets and liabilities. As a subject of study, it is related to but distinct from economics, which is the study of the production, distribution, and consumption of goods and services. Based on the scope of financial activities in financial systems, the discipline can be divided into personal, corporate, and public finance.\nIn these financial systems, assets are bought, sold, or traded as financial instruments, such as currencies, loans, bonds, shares, stocks, options, futures, etc. Assets can also be banked, invested, and insured to maximize value and minimize loss. In practice, risks are always present in any financial action and entities.'), 0.025459158132064674), (Document(id='a72385c4-4d6c-4a88-a221-95fda6e17d7c', metadata={}, page_content='Quantum finance involves applying quantum mechanical approaches to financial theory, providing novel methods and perspectives in the field.  Quantum finance is an interdisciplinary field, in which theories and methods developed by quantum physicists and economists are applied to solve financial problems. It represents a branch known as econophysics. Although quantum computational methods have been around for quite some time and use the basic principles of physics to better understand the ways to implement and manage cash flows, it is mathematics that is actually important in this new scenario Finance theory is heavily based on financial instrument pricing such as stock option pricing. Many of the problems facing the finance community have no known analytical solution. As a result, numerical methods and computer simulations for solving these problems have proliferated. This research area is known as computational finance. Many computational finance problems have a high degree of computational complexity and  ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  51%|█████████████████████████████████████████████████▌                                               | 2047/4006 [01:06<01:04, 30.27it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on the management of personal finances;\nUnderstanding the effects of credit on individual financial standing;\nDeveloping a savings plan or financing for large purchases (auto, education, home);\nPlanning a secure financial future in an environment of economic instability;\nPursuing a checking or a savings account;\nPreparing for retirement or other long term expenses.'), 0.09914036299250673), (Document(id='85a1cdd5-494e-461f-8d47-199729cd13b7', metadata={}, page_content='Finance refers to monetary resources and to the study and discipline of money, currency, assets and liabilities. As a subject of study, it is related to but distinct from economics, which is the study of the production, distribution, and consumption of goods and services. Based on the scope of financial activities in financial systems, the discipline can be divided into personal, corporate, and public finance.\nIn these financial systems, assets are bought, sold, or traded as financial instruments, such as currencies, loans, bonds, shares, stocks, options, futures, etc. Assets can also be banked, invested, and insured to maximize value and minimize loss. In practice, risks are always present in any financial action and entities.'), 0.0785074575976955), (Document(id='1ba995b8-d300-4680-bc86-fa75f07f38e2', metadata={}, page_content='Challenges\nIn addition to risks and challenges inherent to any financial services provider, agricultural financial service providers face additional risks and challenges specific to agriculture and rural areas. These challenges are related to seasonality of farming business and low population density in rural areas.\nSome agricultural activities involve long gestation periods up to several years (for tree crops). Many require large capital investments, for example for farm equipment. This leads to a slow rotation of the invested capital. Lenders need to offer longer loan maturities and less frequent or irregular repayment installments to match the cash flow of borrowers.\nLonger loan maturities and irregular repayment schedules are more risky and present additional challenges to liquidity management. Moreover, the slower rotation of capital results in a lower profitability of agriculture and related activities.'), 0.07800295982102012), (Document(id='7d9f406a-72e2-4ce9-9b3e-4e6de3e4a143', metadata={}, page_content='Areas of finance\nAs outlined, finance comprises, broadly, the three areas of personal finance, corporate finance, and public finance.These, in turn, overlap and employ various activities and sub-disciplines—chiefly investments, risk management, and quantitative finance.\n\nPersonal finance\nPersonal finance refers to the practice of budgeting to ensure enough funds are available to meet basic needs, while ensuring there is only a reasonable level of risk to lose said capital. Personal finance may involve paying for education, financing durable goods such as real estate and cars, buying insurance, investing, and saving for retirement. Personal finance may also involve paying for a loan or other debt obligations. The main areas of personal finance are considered to be income, spending, saving, investing, and protection. The following steps, as outlined by the Financial Planning Standards Board, suggest that an individual will understand a potentially secure personal finance plan after:'), 0.05896219377555656), (Document(id='4d3c5638-63de-4c99-a49b-052ccee340dd', metadata={}, page_content='The demand side of agricultural finance sector is also diver ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  54%|████████████████████████████████████████████████████▍                                            | 2166/4006 [01:10<00:58, 31.35it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.13132335934063732), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.04676068113165266), (Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on the management of personal finances;\nUnderstanding the effects of credit on individual financial standing;\nDeveloping a savings plan or financing for large purchases (auto, education, home);\nPlanning a secure financial future in an environment of economic instability;\nPursuing a checking or a savings account;\nPreparing for retirement or other long term expenses.'), 0.042842962975171095), (Document(id='90cb692e-ab61-4d21-a167-a93e3c0c5332', metadata={}, page_content='External links\n\nFinance Definition (Investopedia)\nHypertextual Finance Glossary (Campbell Harvey)\nFinance Glossary (Pierre Vernimmen)\nGlossary of financial risk management terms (Risk.net)\nGlossary of Key Investment Terms (PIMCO)\nCorporate finance resources (Aswath Damodaran)\nFinancial management resources (James Van Horne)\nPersonal finance resources (Financial Literacy and Education Commission, mymoney.gov)\nPublic finance resources (Governance and Social Development Resource Centre, gsdrc.org) [Archived 2023-06-02 at the Wayback Machine]\nRisk management resources (Global Risk Institute)'), 0.03637915370014633), (Document(id='7d9f406a-72e2-4ce9-9b3e-4e6de3e4a143', metadata={}, page_content='Areas of finance\nAs outlined, finance comprises, broadly, the three areas of personal finance, corporate finance, and public finance.These, in turn, overlap and employ various activities and sub-disciplines—chiefly investments, risk management, and quantitative finance.\n\nPersonal finance\nPersonal finance refers to the practice of budgeting to ensure enough funds are available to meet basic needs, while ensuring there is only a reasonable level of risk to lose said capital. Personal finance may involve paying for education, financing durable goods such as real estate and cars, buying insurance, investing, and saving for retirement. Personal finance may also involve paying for a loan or other debt obligations. The main areas of personal finance are considered to be income, spending, saving, investing, and protection. The following steps, as outlined by the Financial Planning Standards Board, suggest that an individual will understand a potentially secure personal finance plan after:'), 0.026087904818150265), (Document(id='81493b73-d890-4f77-bf87-35a75cbd6875', metadata={}, page_content="Financial planning and forecasting\nCapital budgeting\nCapital structure\nWorking capital management\nRisk management\nFinancial analysis and reporting.\nThe discussion, however, extends to business strategy more broadly, emphasizing alignment with the company's overall strategic objectives; and similarly incorporates the managerial perspectives of planning, directing, and controlling.\n\nFinancial economics\nFinancial economics is the branch of economics that studies the interrelation of financial variables, such as prices, interest rates and shares, as opposed to real economic variables, i.e. goods and services. It thus centers on pricing, decision making, and risk management in the financial markets, and produces many of the commonly employed financial models. (Financial econometrics is the branch of financial economics that uses econometric techniques to parameterize the relationships suggested.)\nThe discipline has two  ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  62%|████████████████████████████████████████████████████████████▍                                    | 2498/4006 [01:21<00:48, 31.29it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.13789809912094275), (Document(id='dc0b3218-e165-43ae-84c0-83fa1decff28', metadata={}, page_content='Corporate finance\nCorporate finance deals with the actions that managers take to increase the value of the firm to the shareholders, the sources of funding and the capital structure of corporations, and the tools and analysis used to allocate financial resources. While corporate finance is in principle different from managerial finance, which studies the financial management of all firms rather than corporations alone, the concepts are applicable to the financial problems of all firms, and this area is then often referred to as "business finance".\nTypically, "corporate finance" relates to the long term objective of maximizing the value of the entity\'s assets, its stock, and its return to shareholders, while also balancing risk and profitability. This entails three primary areas:'), 0.07877753460295334), (Document(id='81493b73-d890-4f77-bf87-35a75cbd6875', metadata={}, page_content="Financial planning and forecasting\nCapital budgeting\nCapital structure\nWorking capital management\nRisk management\nFinancial analysis and reporting.\nThe discussion, however, extends to business strategy more broadly, emphasizing alignment with the company's overall strategic objectives; and similarly incorporates the managerial perspectives of planning, directing, and controlling.\n\nFinancial economics\nFinancial economics is the branch of economics that studies the interrelation of financial variables, such as prices, interest rates and shares, as opposed to real economic variables, i.e. goods and services. It thus centers on pricing, decision making, and risk management in the financial markets, and produces many of the commonly employed financial models. (Financial econometrics is the branch of financial economics that uses econometric techniques to parameterize the relationships suggested.)\nThe discipline has two main areas of focus: asset pricing and corporate finance; the first being the perspective of providers of capital, i.e. investors, and the second of users of capital; respectively:"), 0.0722306117426651), (Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on the management of personal finances;\nUnderstanding the effects of credit on individual financial standing;\nDeveloping a savings plan or financing for large purchases (auto, education, home);\nPlanning a secure financial future in an environment of economic instability;\nPursuing a checking or a savings account;\nPreparing for retirement or other long term expenses.'), 0.06574572904338494), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.06524485589568141), (Document(id='d0f8cb97-43fb-4b1e-ab7d-5231c3d80437', metadata={}, page_content='Public finance\nPublic finance describes finance as related to sovereign states, sub-national entities, and related public entities or agencies. It generally encompasses a long-term strategic perspective regarding investment decisions that affect public entities. These long-term strategic periods typically encompass five or more years. Public finance is primarily concerned with:'), 0.06029513000656206), (Document(id='7d9f406a-72e2-4ce9-9b3e-4e6de3e4a143', metadata={}, page_content='Areas of finance\nAs outlined, finance comprises, broadly, the three areas of personal finance, corporate finance, and public finance.These, in turn ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  62%|████████████████████████████████████████████████████████████▌                                    | 2502/4006 [01:21<00:48, 30.97it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.17686825536587358), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.15781063058100564), (Document(id='81493b73-d890-4f77-bf87-35a75cbd6875', metadata={}, page_content="Financial planning and forecasting\nCapital budgeting\nCapital structure\nWorking capital management\nRisk management\nFinancial analysis and reporting.\nThe discussion, however, extends to business strategy more broadly, emphasizing alignment with the company's overall strategic objectives; and similarly incorporates the managerial perspectives of planning, directing, and controlling.\n\nFinancial economics\nFinancial economics is the branch of economics that studies the interrelation of financial variables, such as prices, interest rates and shares, as opposed to real economic variables, i.e. goods and services. It thus centers on pricing, decision making, and risk management in the financial markets, and produces many of the commonly employed financial models. (Financial econometrics is the branch of financial economics that uses econometric techniques to parameterize the relationships suggested.)\nThe discipline has two main areas of focus: asset pricing and corporate finance; the first being the perspective of providers of capital, i.e. investors, and the second of users of capital; respectively:"), 0.0717787975266283), (Document(id='d3d44fbc-79c9-4683-8ad5-6e39f4f35304', metadata={}, page_content="Agricultural sector depends significantly on external factors such as the weather, pest and disease outbreaks and prices of inputs and outputs, which are beyond the farmers' control. This translates to additional risks for agricultural financial institutions. These risks are exacerbated by the fact that they are common for most or all farmers in the area. For rural\nfinancial institutions, this translates into considerable portfolio risk.\nLow population densities and poor infrastructure result in high transaction costs for rural financial service providers and for their clients. This increases the costs of financial services, thereby reducing the effective demand for loans. \nAdditionally, agriculture is a politically sensitive topic, prone to government interventions, such as:"), 0.05051588104027638), (Document(id='7d9f406a-72e2-4ce9-9b3e-4e6de3e4a143', metadata={}, page_content='Areas of finance\nAs outlined, finance comprises, broadly, the three areas of personal finance, corporate finance, and public finance.These, in turn, overlap and employ various activities and sub-disciplines—chiefly investments, risk management, and quantitative finance.\n\nPersonal finance\nPersonal finance refers to the practice of budgeting to ensure enough funds are available to meet basic needs, while ensuring there is only a reasonable level of risk to lose said capital. Personal finance may involve paying for education, financing durable goods such as real estate and cars, buying insurance, investing, and saving for retirement. Personal finance may also involve paying for a loan or other debt obligations. The main areas of personal finance are considered to be income, spending, saving, investing, and protection. The following steps, as outlined by the Financial Planning Standards Board, suggest that an individual will understand a potentially secure personal finance plan after:'), 0.04781376228854595), (Document(id='90cb692e-ab61-4d21-a167-a93e3c0c5332', metadata={}, page_content='External links\n\nFinance Definition (Investopedia)\nHypertextual Finance Glossary (Campbell Harvey)\nFinance Glossary (Pierre Vernimmen)\nGlossary of financ ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  63%|████████████████████████████████████████████████████████████▉                                    | 2518/4006 [01:21<00:48, 30.88it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='4d3c5638-63de-4c99-a49b-052ccee340dd', metadata={}, page_content='The demand side of agricultural finance sector is also diverse, ranging from semi-subsistence households to micro and small enterprises engaged in agricultural activities, and medium/large companies engaged in production, manufacturing, trade and services. Their financial needs differ widely in terms of amounts, terms and conditions as well as the degree of sophistication of financial services required.'), 0.06229449220622185), (Document(id='1ba995b8-d300-4680-bc86-fa75f07f38e2', metadata={}, page_content='Challenges\nIn addition to risks and challenges inherent to any financial services provider, agricultural financial service providers face additional risks and challenges specific to agriculture and rural areas. These challenges are related to seasonality of farming business and low population density in rural areas.\nSome agricultural activities involve long gestation periods up to several years (for tree crops). Many require large capital investments, for example for farm equipment. This leads to a slow rotation of the invested capital. Lenders need to offer longer loan maturities and less frequent or irregular repayment installments to match the cash flow of borrowers.\nLonger loan maturities and irregular repayment schedules are more risky and present additional challenges to liquidity management. Moreover, the slower rotation of capital results in a lower profitability of agriculture and related activities.'), 0.05186812052789991), (Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on the management of personal finances;\nUnderstanding the effects of credit on individual financial standing;\nDeveloping a savings plan or financing for large purchases (auto, education, home);\nPlanning a secure financial future in an environment of economic instability;\nPursuing a checking or a savings account;\nPreparing for retirement or other long term expenses.'), 0.02505800442793804), (Document(id='9787a6e6-fe52-4455-b7f5-8bb0ba271079', metadata={}, page_content="Experimental finance\nExperimental finance aims to establish different market settings and environments to experimentally observe and provide a lens through which science can analyze agents' behavior and the resulting characteristics of trading flows, information diffusion, and aggregation, price setting mechanisms, and returns processes. Researchers in experimental finance can study to what extent existing financial economics theory makes valid predictions and therefore prove them, as well as attempt to discover new principles on which such theory can be extended and be applied to future financial decisions. Research may proceed by conducting trading simulations or by establishing and studying the behavior of people in artificial, competitive, market-like settings."), 0.00411734274530029), (Document(id='267a7746-f00f-4969-85a6-f30a2edae661', metadata={}, page_content='Additional to diversification, the fundamental risk mitigant here, investment managers will apply various hedging techniques as appropriate, these may relate to the portfolio as a whole or to individual stocks. Bond portfolios are often (instead) managed via cash flow matching or immunization, while for derivative portfolios and positions, traders use "the Greeks" to measure and then offset sensitivities. In parallel, managers – active and passive – will monitor tracking error, thereby minimizing and preempting any underperformance vs their "benchmark".'), 0.0006677917820777646), (Document(id='0cf0b842-2d04 ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  75%|████████████████████████████████████████████████████████████████████████▌                        | 2997/4006 [01:37<00:32, 31.30it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='85a1cdd5-494e-461f-8d47-199729cd13b7', metadata={}, page_content='Finance refers to monetary resources and to the study and discipline of money, currency, assets and liabilities. As a subject of study, it is related to but distinct from economics, which is the study of the production, distribution, and consumption of goods and services. Based on the scope of financial activities in financial systems, the discipline can be divided into personal, corporate, and public finance.\nIn these financial systems, assets are bought, sold, or traded as financial instruments, such as currencies, loans, bonds, shares, stocks, options, futures, etc. Assets can also be banked, invested, and insured to maximize value and minimize loss. In practice, risks are always present in any financial action and entities.'), 0.08393622456698979), (Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on the management of personal finances;\nUnderstanding the effects of credit on individual financial standing;\nDeveloping a savings plan or financing for large purchases (auto, education, home);\nPlanning a secure financial future in an environment of economic instability;\nPursuing a checking or a savings account;\nPreparing for retirement or other long term expenses.'), 0.079441600348091), (Document(id='cecb5593-c9e3-4e34-b5a6-3d9dd15868bf', metadata={}, page_content='Much of corporate finance theory, by contrast, considers investment under "certainty" (Fisher separation theorem, "theory of investment value", and Modigliani–Miller theorem). Here, theory and methods are developed for the decisioning about funding, dividends, and capital structure discussed above. A recent development is to incorporate uncertainty and contingency—and thus various elements of asset pricing—into these decisions, employing for example real options analysis.'), 0.022496234681748883), (Document(id='76187b9e-56ac-4c99-a59e-2f8d28ac4da4', metadata={}, page_content='Risk management\nRisk management, in general, is the study of how to control risks and balance the possibility of gains; it is the process of measuring risk and then developing and implementing strategies to manage that risk. \nFinancial risk management is the practice of protecting corporate value against financial risks, often by "hedging" exposure to these using financial instruments. The focus is particularly on credit and market risk, and in banks, through regulatory capital, includes operational risk.'), 0.010297419436149702), (Document(id='7d9f406a-72e2-4ce9-9b3e-4e6de3e4a143', metadata={}, page_content='Areas of finance\nAs outlined, finance comprises, broadly, the three areas of personal finance, corporate finance, and public finance.These, in turn, overlap and employ various activities and sub-disciplines—chiefly investments, risk management, and quantitative finance.\n\nPersonal finance\nPersonal finance refers to the practice of budgeting to ensure enough funds are available to meet basic needs, while ensuring there is only a reasonable level of risk to lose said capital. Personal finance may involve paying for education, financing durable goods such as real estate and cars, buying insurance, investing, and saving for retirement. Personal finance may also involve paying for a loan or other debt obligations. The main areas of personal finance are considered to be income, spending, saving, investing, and protection. The following steps, as outlined by the Financial Planning Standards Board, suggest that an individual will understand a potentially secure personal finance plan af ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  78%|███████████████████████████████████████████████████████████████████████████▍                     | 3115/4006 [01:41<00:31, 28.71it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.08446162718052652), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.016077185359842705), (Document(id='7d9f406a-72e2-4ce9-9b3e-4e6de3e4a143', metadata={}, page_content='Areas of finance\nAs outlined, finance comprises, broadly, the three areas of personal finance, corporate finance, and public finance.These, in turn, overlap and employ various activities and sub-disciplines—chiefly investments, risk management, and quantitative finance.\n\nPersonal finance\nPersonal finance refers to the practice of budgeting to ensure enough funds are available to meet basic needs, while ensuring there is only a reasonable level of risk to lose said capital. Personal finance may involve paying for education, financing durable goods such as real estate and cars, buying insurance, investing, and saving for retirement. Personal finance may also involve paying for a loan or other debt obligations. The main areas of personal finance are considered to be income, spending, saving, investing, and protection. The following steps, as outlined by the Financial Planning Standards Board, suggest that an individual will understand a potentially secure personal finance plan after:'), 0.008375438850355965), (Document(id='d3d44fbc-79c9-4683-8ad5-6e39f4f35304', metadata={}, page_content="Agricultural sector depends significantly on external factors such as the weather, pest and disease outbreaks and prices of inputs and outputs, which are beyond the farmers' control. This translates to additional risks for agricultural financial institutions. These risks are exacerbated by the fact that they are common for most or all farmers in the area. For rural\nfinancial institutions, this translates into considerable portfolio risk.\nLow population densities and poor infrastructure result in high transaction costs for rural financial service providers and for their clients. This increases the costs of financial services, thereby reducing the effective demand for loans. \nAdditionally, agriculture is a politically sensitive topic, prone to government interventions, such as:"), -0.018339678253062264), (Document(id='81493b73-d890-4f77-bf87-35a75cbd6875', metadata={}, page_content="Financial planning and forecasting\nCapital budgeting\nCapital structure\nWorking capital management\nRisk management\nFinancial analysis and reporting.\nThe discussion, however, extends to business strategy more broadly, emphasizing alignment with the company's overall strategic objectives; and similarly incorporates the managerial perspectives of planning, directing, and controlling.\n\nFinancial economics\nFinancial economics is the branch of economics that studies the interrelation of financial variables, such as prices, interest rates and shares, as opposed to real economic variables, i.e. goods and services. It thus centers on pricing, decision making, and risk management in the financial markets, and produces many of the commonly employed financial models. (Financial econometrics is the branch of financial economics that uses econometric techniques to parameterize the relationships suggested.)\nThe discipline has two main areas of focus: asset pricing and corporate finance; the first being the perspective of providers of capital, i.e. investors, and the second of users of capital; respectively:"), -0.029063185213386022), (Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on t ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  79%|████████████████████████████████████████████████████████████████████████████▏                    | 3145/4006 [01:42<00:27, 30.78it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.15128612984412526), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.025238645820655714), (Document(id='a72385c4-4d6c-4a88-a221-95fda6e17d7c', metadata={}, page_content='Quantum finance involves applying quantum mechanical approaches to financial theory, providing novel methods and perspectives in the field.  Quantum finance is an interdisciplinary field, in which theories and methods developed by quantum physicists and economists are applied to solve financial problems. It represents a branch known as econophysics. Although quantum computational methods have been around for quite some time and use the basic principles of physics to better understand the ways to implement and manage cash flows, it is mathematics that is actually important in this new scenario Finance theory is heavily based on financial instrument pricing such as stock option pricing. Many of the problems facing the finance community have no known analytical solution. As a result, numerical methods and computer simulations for solving these problems have proliferated. This research area is known as computational finance. Many computational finance problems have a high degree of computational complexity and are slow to converge to a solution on classical computers. In particular, when it comes to option pricing, there is additional complexity resulting from the need to respond to'), 0.023190477570420365), (Document(id='d3d44fbc-79c9-4683-8ad5-6e39f4f35304', metadata={}, page_content="Agricultural sector depends significantly on external factors such as the weather, pest and disease outbreaks and prices of inputs and outputs, which are beyond the farmers' control. This translates to additional risks for agricultural financial institutions. These risks are exacerbated by the fact that they are common for most or all farmers in the area. For rural\nfinancial institutions, this translates into considerable portfolio risk.\nLow population densities and poor infrastructure result in high transaction costs for rural financial service providers and for their clients. This increases the costs of financial services, thereby reducing the effective demand for loans. \nAdditionally, agriculture is a politically sensitive topic, prone to government interventions, such as:"), 0.02193247843606716), (Document(id='81493b73-d890-4f77-bf87-35a75cbd6875', metadata={}, page_content="Financial planning and forecasting\nCapital budgeting\nCapital structure\nWorking capital management\nRisk management\nFinancial analysis and reporting.\nThe discussion, however, extends to business strategy more broadly, emphasizing alignment with the company's overall strategic objectives; and similarly incorporates the managerial perspectives of planning, directing, and controlling.\n\nFinancial economics\nFinancial economics is the branch of economics that studies the interrelation of financial variables, such as prices, interest rates and shares, as opposed to real economic variables, i.e. goods and services. It thus centers on pricing, decision making, and risk management in the financial markets, and produces many of the commonly employed financial models. (Financial econometrics is the branch of financial economics that uses econometric techniques to parameterize the relationships suggested.)\nThe discipline has two main areas of focus: asset pricing and corporate finance; the first being the perspective of providers of capital, i.e. investors, and the second of users of capital; respectively:"), 0.002990251722422066), (Document(id='d0f8cb97-43fb-4b1e-ab ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  90%|██████████████████████████████████████████████████████████████████████████████████████▉          | 3588/4006 [01:56<00:13, 31.00it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='cc502a94-4b96-4f9f-a5ed-8d01d8842611', metadata={}, page_content='Quantum finance'), 0.20063022708783063), (Document(id='4b29a347-e0bc-4f56-82a4-b5335478d6ee', metadata={}, page_content='See also\n2007–2008 financial crisis\nOutline of finance'), 0.10712828660338236), (Document(id='81493b73-d890-4f77-bf87-35a75cbd6875', metadata={}, page_content="Financial planning and forecasting\nCapital budgeting\nCapital structure\nWorking capital management\nRisk management\nFinancial analysis and reporting.\nThe discussion, however, extends to business strategy more broadly, emphasizing alignment with the company's overall strategic objectives; and similarly incorporates the managerial perspectives of planning, directing, and controlling.\n\nFinancial economics\nFinancial economics is the branch of economics that studies the interrelation of financial variables, such as prices, interest rates and shares, as opposed to real economic variables, i.e. goods and services. It thus centers on pricing, decision making, and risk management in the financial markets, and produces many of the commonly employed financial models. (Financial econometrics is the branch of financial economics that uses econometric techniques to parameterize the relationships suggested.)\nThe discipline has two main areas of focus: asset pricing and corporate finance; the first being the perspective of providers of capital, i.e. investors, and the second of users of capital; respectively:"), 0.028644364061427008), (Document(id='a72385c4-4d6c-4a88-a221-95fda6e17d7c', metadata={}, page_content='Quantum finance involves applying quantum mechanical approaches to financial theory, providing novel methods and perspectives in the field.  Quantum finance is an interdisciplinary field, in which theories and methods developed by quantum physicists and economists are applied to solve financial problems. It represents a branch known as econophysics. Although quantum computational methods have been around for quite some time and use the basic principles of physics to better understand the ways to implement and manage cash flows, it is mathematics that is actually important in this new scenario Finance theory is heavily based on financial instrument pricing such as stock option pricing. Many of the problems facing the finance community have no known analytical solution. As a result, numerical methods and computer simulations for solving these problems have proliferated. This research area is known as computational finance. Many computational finance problems have a high degree of computational complexity and are slow to converge to a solution on classical computers. In particular, when it comes to option pricing, there is additional complexity resulting from the need to respond to'), -0.005613521638894836), (Document(id='dc0b3218-e165-43ae-84c0-83fa1decff28', metadata={}, page_content='Corporate finance\nCorporate finance deals with the actions that managers take to increase the value of the firm to the shareholders, the sources of funding and the capital structure of corporations, and the tools and analysis used to allocate financial resources. While corporate finance is in principle different from managerial finance, which studies the financial management of all firms rather than corporations alone, the concepts are applicable to the financial problems of all firms, and this area is then often referred to as "business finance".\nTypically, "corporate finance" relates to the long term objective of maximizing the value of the entity\'s assets, its stock, and its return to shareholders, while also balancing risk and profitability. This entails three primary areas:'), -0.03256777996076399), (Document(id='90cb692e-ab61-4d2 ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context:  94%|███████████████████████████████████████████████████████████████████████████████████████████▍     | 3776/4006 [02:02<00:07, 31.88it/s]/tmp/ipykernel_27568/3928244748.py:87: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='4a0511db-343c-4775-869a-6edc87c08e8a', metadata={}, page_content='Behavioral finance\nBehavioral finance studies how the psychology of investors or managers affects financial decisions and markets \nand is relevant when making a decision that can impact either negatively or positively on one of their areas. With more in-depth research into behavioral finance, it is possible to bridge what actually happens in financial markets with analysis based on financial theory. Behavioral finance has grown over the last few decades to become an integral aspect of finance.\nBehavioral finance includes such topics as:\n\nEmpirical studies that demonstrate significant deviations from classical theories;\nModels of how psychology affects and impacts trading and prices;\nForecasting based on these methods;\nStudies of experimental asset markets and the use of models to forecast experiments.\nA strand of behavioral finance has been dubbed quantitative behavioral finance, which uses mathematical and statistical methodology to understand behavioral biases in conjunction with valuation.'), 0.06279941145138235), (Document(id='2815a4a2-e2d6-46a6-9a31-e912c77cbf89', metadata={}, page_content='Purchasing insurance to ensure protection against unforeseen personal events;\nUnderstanding the effects of tax policies, subsidies, or penalties on the management of personal finances;\nUnderstanding the effects of credit on individual financial standing;\nDeveloping a savings plan or financing for large purchases (auto, education, home);\nPlanning a secure financial future in an environment of economic instability;\nPursuing a checking or a savings account;\nPreparing for retirement or other long term expenses.'), 0.036652265278496854), (Document(id='9787a6e6-fe52-4455-b7f5-8bb0ba271079', metadata={}, page_content="Experimental finance\nExperimental finance aims to establish different market settings and environments to experimentally observe and provide a lens through which science can analyze agents' behavior and the resulting characteristics of trading flows, information diffusion, and aggregation, price setting mechanisms, and returns processes. Researchers in experimental finance can study to what extent existing financial economics theory makes valid predictions and therefore prove them, as well as attempt to discover new principles on which such theory can be extended and be applied to future financial decisions. Research may proceed by conducting trading simulations or by establishing and studying the behavior of people in artificial, competitive, market-like settings."), 0.022698876729389306), (Document(id='d2cdaf49-c2d7-47de-a044-e4c859cb157e', metadata={}, page_content="Portfolio optimization is the process of selecting the best portfolio given the client's objectives and constraints.\nFundamental analysis is the approach typically applied in valuing and evaluating the individual securities.\nTechnical analysis is about forecasting future asset prices with past data.\nOverlaid is the portfolio manager's investment style—broadly, active vs passive, value vs growth, and small cap vs. large cap—and investment strategy.\nIn a well-diversified portfolio, achieved investment performance will, in general, largely be a function of the asset mix selected, while the individual securities are less impactful. The specific approach or philosophy will also be significant, depending on the extent to which it is complementary with the market cycle.\nRisk management here is discussed immediately below.\nA quantitative fund is managed using computer-based mathematical techniques (increasingly, machine learning) instead of human judgment. The actual trading is typically automated via sophisticated algo ...
Key Investment Terms (PIMCO)\nCorporate finance resources (Aswath Damodaran)\nFinancial management resources (James Van Horne)\nPersonal finance resources (Financial Literacy and Education Commission, mymoney.gov)\nPublic finance resources (Governance and Social Development Resource Centre, gsdrc.org) [Archived 2023-06-02 at the Wayback Machine]\nRisk management resources (Global Risk Institute)'), -0.12894573709389845), (Document(id='e0a864ec-f244-4167-bc56-15a0e766cadf', metadata={}, page_content='The subject has a close relationship with financial economics, which, as outlined, is concerned with much of the underlying theory that is involved in financial mathematics:  generally, financial mathematics will derive and extend the mathematical models suggested. Computational finance is the branch of (applied) computer science that deals with problems of practical interest in finance, and especially emphasizes the numerical methods applied here.'), -0.14978103165525902), (Document(id='4b29a347- ...
#   results = vectorstore.similarity_search_with_relevance_scores(query, k=k)
# Retrieving context: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 4006/4006 [02:10<00:00, 30.81it/s]
# ✅ Context saved to ./queries_with_context_latest.csv

# %%
# !pip install -U langchain-community

# %%
# pip uninstall nltk

# %%
# !pip uninstall -y tensorflow
# !pip install --no-cache-dir tensorflow

# %%
# !pip uninstall -y safetensors
# !pip install --no-cache-dir safetensors
# Out:
# Found existing installation: safetensors 0.4.3
# Uninstalling safetensors-0.4.3:
#   Successfully uninstalled safetensors-0.4.3
# Collecting safetensors
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Installing collected packages: safetensors
# Successfully installed safetensors-0.5.3

# %%
# !pip uninstall -y transformers sentencepiece
# !rm -rf ~/.cache/huggingface
# Out:
# Found existing installation: transformers 4.46.3
# Uninstalling transformers-4.46.3:
#   Successfully uninstalled transformers-4.46.3
# Found existing installation: sentencepiece 0.2.0
# Uninstalling sentencepiece-0.2.0:
#   Successfully uninstalled sentencepiece-0.2.0

# %%
pip install --no-cache-dir transformers sentencepiece
# Out:
# Collecting transformers
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: filelock in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (0.26.5)
# Requirement already satisfied: numpy>=1.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (2.32.2)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (2024.7.4)
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 706.7 kB/s eta 0:00:00 0:00:01
# Downloading sentencepiece-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 628.5 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: sentencepiece, transformers
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# llava 1.2.2.post1 requires scikit-learn==1.2.2, but you have scikit-learn 1.3.2 which is incompatible.
# llava 1.2.2.post1 requires sentencepiece==0.1.99, but you have sentencepiece 0.2.0 which is incompatible.
# llava 1.2.2.post1 requires tokenizers==0.15.1, but you have tokenizers 0.20.3 which is incompatible.
# llava 1.2.2.post1 requires torch==2.1.2, but you have torch 2.4.1 which is incompatible.
# llava 1.2.2.post1 requires torchvision==0.16.2, but you have torchvision 0.19.1 which is incompatible.
# llava 1.2.2.post1 requires transformers==4.37.2, but you have transformers 4.46.3 which is incompatible.
# Successfully installed sentencepiece-0.2.0 transformers-4.46.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip uninstall -y sentencepiece transformers
# !pip install --no-cache-dir sentencepiece transformers
# Out:
# Found existing installation: sentencepiece 0.1.99
# Uninstalling sentencepiece-0.1.99:
#   Successfully uninstalled sentencepiece-0.1.99
# Found existing installation: transformers 4.37.2
# Uninstalling transformers-4.37.2:
#   Successfully uninstalled transformers-4.37.2
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting transformers
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (0.26.5)
# Requirement already satisfied: numpy>=1.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (2.32.2)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Downloading tokenizers-0.20.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->transformers) (2024.7.4)
# Downloading sentencepiece-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.1 MB/s eta 0:00:00ta 0:00:01
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 54.3 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 101.2 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.1
#     Uninstalling tokenizers-0.15.1:
#       Successfully uninstalled tokenizers-0.15.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# llava 1.2.2.post1 requires scikit-learn==1.2.2, but you have scikit-learn 1.3.2 which is incompatible.
# llava 1.2.2.post1 requires sentencepiece==0.1.99, but you have sentencepiece 0.2.0 which is incompatible.
# llava 1.2.2.post1 requires tokenizers==0.15.1, but you have tokenizers 0.20.3 which is incompatible.
# llava 1.2.2.post1 requires torch==2.1.2, but you have torch 2.4.1 which is incompatible.
# llava 1.2.2.post1 requires torchvision==0.16.2, but you have torchvision 0.19.1 which is incompatible.
# llava 1.2.2.post1 requires transformers==4.37.2, but you have transformers 4.46.3 which is incompatible.
# Successfully installed sentencepiece-0.2.0 tokenizers-0.20.3 transformers-4.46.3

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (4.37.2)
# Requirement already satisfied: tqdm in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (2.4.1)
# Requirement already satisfied: numpy in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (1.24.4)
# Requirement already satisfied: scikit-learn in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (0.26.5)
# Requirement already satisfied: Pillow in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2025.2.0)
# Requirement already satisfied: packaging>=20.9 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: regex!=2019.12.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.7.24)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.4.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --force-reinstall torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision
#   Downloading torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch)
#   Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting numpy (from torchvision)
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.3 MB/s eta 0:00:0000:0100:08
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.0 MB/s eta 0:00:0000:0100:04
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 2.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:0000:0100:07
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.9 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 3.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.5 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:0000:0100:03
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 2.4 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 2.7 MB/s eta 0:00:0000:0100:03
# Downloading torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading torchaudio-2.4.1-cp38-cp38-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading pillow-10.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 2.8 MB/s eta 0:00:00a 0:00:01
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.0 MB/s eta 0:00:00a 0:00:01
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.5 MB/s eta 0:00:00-:--:--
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 2.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mpmath, typing-extensions, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.1.105
#     Uninstalling nvidia-nvtx-cu12-12.1.105:
#       Successfully uninstalled nvidia-nvtx-cu12-12.1.105
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.40
#     Uninstalling nvidia-nvjitlink-cu12-12.5.40:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.40
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.18.1
#     Uninstalling nvidia-nccl-cu12-2.18.1:
#       Successfully uninstalled nvidia-nccl-cu12-2.18.1
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.2.106
#     Uninstalling nvidia-curand-cu12-10.3.2.106:
#       Successfully uninstalled nvidia-curand-cu12-10.3.2.106
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.0.2.54
#     Uninstalling nvidia-cufft-cu12-11.0.2.54:
#       Successfully uninstalled nvidia-cufft-cu12-11.0.2.54
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.1.105
#     Uninstalling nvidia-cuda-runtime-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.1.105
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.1.105
#     Uninstalling nvidia-cuda-cupti-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.1.105
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.1.3.1
#     Uninstalling nvidia-cublas-cu12-12.1.3.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.1.3.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.3
#     Uninstalling MarkupSafe-2.1.3:
#       Successfully uninstalled MarkupSafe-2.1.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.5.0
#     Uninstalling fsspec-2024.5.0:
#       Successfully uninstalled fsspec-2024.5.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.13.1
#     Uninstalling filelock-3.13.1:
#       Successfully uninstalled filelock-3.13.1
#   Attempting uninstall: triton
#     Found existing installation: triton 2.1.0
#     Uninstalling triton-2.1.0:
#       Successfully uninstalled triton-2.1.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.1.0.106
#     Uninstalling nvidia-cusparse-cu12-12.1.0.106:
#       Successfully uninstalled nvidia-cusparse-cu12-12.1.0.106
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 8.9.2.26
#     Uninstalling nvidia-cudnn-cu12-8.9.2.26:
#       Successfully uninstalled nvidia-cudnn-cu12-8.9.2.26
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.4.5.107
#     Uninstalling nvidia-cusolver-cu12-11.4.5.107:
#       Successfully uninstalled nvidia-cusolver-cu12-11.4.5.107
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.2
#     Uninstalling torchvision-0.16.2:
#       Successfully uninstalled torchvision-0.16.2
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.1+cu118
#     Uninstalling torchaudio-2.4.1+cu118:
#       Successfully uninstalled torchaudio-2.4.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.1.0 requires fsspec[http]<=2024.9.0,>=2023.1.0, but you have fsspec 2025.2.0 which is incompatible.
# gradio 4.16.0 requires aiofiles<24.0,>=22.0, but you have aiofiles 24.1.0 which is incompatible.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# llava 1.2.2.post1 requires scikit-learn==1.2.2, but you have scikit-learn 1.3.2 which is incompatible.
# llava 1.2.2.post1 requires torch==2.1.2, but you have torch 2.4.1 which is incompatible.
# llava 1.2.2.post1 requires torchvision==0.16.2, but you have torchvision 0.19.1 which is incompatible.
# openai-whisper 20231117 requires triton<3,>=2.0.0, but you have triton 3.0.0 which is incompatible.
# tensorflow 2.13.1 requires numpy<=1.24.3,>=1.22, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.13.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# unstructured-client 0.28.1 requires pydantic<2.10.0,>=2.9.2, but you have pydantic 2.10.6 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 filelock-3.16.1 fsspec-2025.2.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.1 numpy-1.24.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.1.105 pillow-10.4.0 sympy-1.13.3 torch-2.4.1 torchaudio-2.4.1 torchvision-0.19.1 triton-3.0.0 typing-extensions-4.12.2

# %%
# !pip install --upgrade --force-reinstall pydantic
# Out:
# Collecting pydantic
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting annotated-types>=0.6.0 (from pydantic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic)
#   Downloading pydantic_core-2.27.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.12.2 (from pydantic)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.3 MB/s eta 0:00:00ta 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, pydantic-core, annotated-types, pydantic
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.16.0 requires aiofiles<24.0,>=22.0, but you have aiofiles 24.1.0 which is incompatible.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# llava 1.2.2.post1 requires scikit-learn==1.2.2, but you have scikit-learn 1.3.2 which is incompatible.
# tensorflow 2.13.1 requires numpy<=1.24.3,>=1.22, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.13.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# torchaudio 2.4.1+cu118 requires torch==2.4.1, but you have torch 2.1.2 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.1.2 which is incompatible.
# unstructured-client 0.28.1 requires pydantic<2.10.0,>=2.9.2, but you have pydantic 2.10.6 which is incompatible.
# Successfully installed annotated-types-0.7.0 pydantic-2.10.6 pydantic-core-2.27.2 typing-extensions-4.12.2

# %%
# !pip install --upgrade --force-reinstall pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy>=1.20.3 (from pandas)
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 10.0 MB/s eta 0:00:0000:0100:01
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.1
#     Uninstalling tzdata-2024.1:
#       Successfully uninstalled tzdata-2024.1
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.16.0 requires aiofiles<24.0,>=22.0, but you have aiofiles 24.1.0 which is incompatible.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# llava 1.2.2.post1 requires scikit-learn==1.2.2, but you have scikit-learn 1.3.2 which is incompatible.
# tensorflow 2.13.1 requires numpy<=1.24.3,>=1.22, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.13.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed numpy-1.24.4 pandas-2.0.3 python-dateutil-2.9.0.post0 pytz-2025.1 six-1.16.0 tzdata-2025.1

# %%
# !find ~/.miniconda3/envs/finbot3/lib/python3.8/site-packages/ -name "*.so" -delete
# !find ~/.miniconda3/envs/finbot3/lib/python3.8/site-packages/ -name "*.pyc" -delete
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
pip install --upgrade --force-reinstall scikit-learn numpy
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 15.8 MB/s eta 0:00:0000:010:01
# Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 4.4 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.16.0 requires aiofiles<24.0,>=22.0, but you have aiofiles 24.1.0 which is incompatible.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# llava 1.2.2.post1 requires scikit-learn==1.2.2, but you have scikit-learn 1.3.2 which is incompatible.
# tensorflow 2.13.1 requires numpy<=1.24.3,>=1.22, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.13.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed joblib-1.4.2 numpy-1.24.4 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install unstructured
# Out:
# Requirement already satisfied: unstructured in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (0.11.8)
# Requirement already satisfied: chardet in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (5.3.1)
# Requirement already satisfied: nltk in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (2.32.2)
# Requirement already satisfied: beautifulsoup4 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (2024.10.22)
# Requirement already satisfied: langdetect in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (1.24.4)
# Requirement already satisfied: rapidfuzz in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (3.9.7)
# Requirement already satisfied: backoff in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (0.28.1)
# Requirement already satisfied: wrapt in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured) (1.12.1)
# Requirement already satisfied: soupsieve>1.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from dataclasses-json->unstructured) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langdetect->unstructured) (1.15.0)
# Requirement already satisfied: click in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from nltk->unstructured) (2024.7.24)
# Requirement already satisfied: tqdm in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from nltk->unstructured) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->unstructured) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->unstructured) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests->unstructured) (2024.7.4)
# Requirement already satisfied: aiofiles>=24.1.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (42.0.5)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (2.9.2)
# Requirement already satisfied: pypdf>=4.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (5.3.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.16.0)
# Requirement already satisfied: anyio in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (23.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.21)
# Requirement already satisfied: sniffio>=1.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (0.2.19)
# Requirement already satisfied: PyYAML>=5.3 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (0.2.17)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.43 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (1.24.4)
# Requirement already satisfied: requests<3,>=2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain<0.3.0,>=0.2.17->langchain-community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain<0.3.0,>=0.2.17->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain-community) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests<3,>=2->langchain-community) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from requests<3,>=2->langchain-community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.17->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.17->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pypdf
# Out:
# Requirement already satisfied: pypdf in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (5.3.1)
# Requirement already satisfied: typing_extensions>=4.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from pypdf) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (1.60.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /mnt/Data/sarmistha/.miniconda3/envs/finbot3/lib/python3.8/site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Note: you may need to restart the kernel to use updated packages.
